# %%
! pip install streamlit_folium
# Out:
# Collecting streamlit_folium
#   Downloading streamlit_folium-0.20.0-py3-none-any.whl.metadata (416 bytes)
# Requirement already satisfied: streamlit>=1.13.0 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit_folium) (1.33.0)
# Collecting folium!=0.15.0,>=0.13 (from streamlit_folium)
#   Downloading folium-0.16.0-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: jinja2 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit_folium) (3.1.3)
# Collecting branca (from streamlit_folium)
#   Downloading branca-0.7.2-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: numpy in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from folium!=0.15.0,>=0.13->streamlit_folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from folium!=0.15.0,>=0.13->streamlit_folium) (2.31.0)
# Collecting xyzservices (from folium!=0.15.0,>=0.13->streamlit_folium)
#   Downloading xyzservices-2024.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from jinja2->streamlit_folium) (2.1.5)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (8.1.7)
# Requirement already satisfied: packaging<25,>=16.8 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (24.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (10.1.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (16.0.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (0.9.0b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (6.4)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from streamlit>=1.13.0->streamlit_folium) (4.0.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from altair<6,>=4.0->streamlit>=1.13.0->streamlit_folium) (4.21.1)
# Requirement already satisfied: toolz in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from altair<6,>=4.0->streamlit>=1.13.0->streamlit_folium) (0.12.1)
# Requirement already satisfied: colorama in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from click<9,>=7.0->streamlit>=1.13.0->streamlit_folium) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.13.0->streamlit_folium) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=1.13.0->streamlit_folium) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=1.13.0->streamlit_folium) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=1.13.0->streamlit_folium) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from requests->folium!=0.15.0,>=0.13->streamlit_folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from requests->folium!=0.15.0,>=0.13->streamlit_folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from requests->folium!=0.15.0,>=0.13->streamlit_folium) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from requests->folium!=0.15.0,>=0.13->streamlit_folium) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from rich<14,>=10.14.0->streamlit>=1.13.0->streamlit_folium) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from rich<14,>=10.14.0->streamlit>=1.13.0->streamlit_folium) (2.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.13.0->streamlit_folium) (5.0.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit_folium) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit_folium) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit_folium) (0.35.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit_folium) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.13.0->streamlit_folium) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\adminos\anaconda3\envs\amira\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit>=1.13.0->streamlit_folium) (1.16.0)
# Downloading streamlit_folium-0.20.0-py3-none-any.whl (326 kB)
#    ---------------------------------------- 0.0/326.7 kB ? eta -:--:--
#    - -------------------------------------- 10.2/326.7 kB ? eta -:--:--
#    - -------------------------------------- 10.2/326.7 kB ? eta -:--:--
#    ------- ------------------------------- 61.4/326.7 kB 544.7 kB/s eta 0:00:01
#    ---------------- --------------------- 143.4/326.7 kB 944.1 kB/s eta 0:00:01
#    ------------------------------- -------- 256.0/326.7 kB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 317.4/326.7 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 326.7/326.7 kB 1.3 MB/s eta 0:00:00
# Downloading folium-0.16.0-py2.py3-none-any.whl (100 kB)
#    ---------------------------------------- 0.0/100.0 kB ? eta -:--:--
#    ---------------------------------------- 100.0/100.0 kB 5.6 MB/s eta 0:00:00
# Downloading branca-0.7.2-py3-none-any.whl (25 kB)
# Downloading xyzservices-2024.4.0-py3-none-any.whl (81 kB)
#    ---------------------------------------- 0.0/82.0 kB ? eta -:--:--
#    ------------------- -------------------- 41.0/82.0 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 82.0/82.0 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: xyzservices, branca, folium, streamlit_folium
# Successfully installed branca-0.7.2 folium-0.16.0 streamlit_folium-0.20.0 xyzservices-2024.4.0

# %%
# %%writefile app1.py

import pandas as pd 
import streamlit as st
import plotly.express as px 

df = pd.read_csv('food_edited.csv')

def income():
    
    tab1 , tab2 , tab3 , tab4 , tab5 = st.tabs(['Gender' , 'Age' , 'Marital Status','Eduactional' , 'Occupation'])
    
    with tab1 :
        st.plotly_chart(px.histogram(data_frame=df , x='monthly income' , color='gender',
            category_orders={'monthly income': df['monthly income'].value_counts().index},text_auto=True , 
            title='Distribution of Monthly Income with Gender'))
        
    with tab2 :
            average_age = df.groupby('monthly income')['age'].mean().reset_index()
            fig = px.bar(average_age, x='monthly income', y='age',
            labels={'monthly income': 'Monthly Income', 'age': 'Average Age'},
            title='Average age by Monthly Income')
            st.plotly_chart(fig)
        
    with tab3 :
        st.plotly_chart(px.histogram(data_frame=df , x='monthly income' , color='marital status',
            category_orders={'monthly income': df['monthly income'].value_counts().index},text_auto=True
            ,title='Distribution of Monthly Income with Marital Status'))
        
    with tab4 :
        st.plotly_chart(px.histogram(data_frame=df , x='monthly income' , color='educational qualifications',
            category_orders={'monthly income': df['monthly income'].value_counts().index},text_auto=True
            ,title='Distribution of Monthly Income with Educational Qualifications'))
        
    with tab5 :
        st.plotly_chart(px.histogram(data_frame=df , x='monthly income' , color='occupation',
            category_orders={'monthly income': df['monthly income'].value_counts().index},text_auto=True
            ,title='Distribution of Monthly Income with Occupation'))
        
##############################################################################################################        

def gender():
    
    tab1 , tab2 , tab3 , tab4 , tab5 ,tab6 = st.tabs(['Family Size' , 'Age' , 'Marital Status','Eduactional' , 'Feedback','Occupation'])
    
    with tab1:
        st.plotly_chart(px.histogram(data_frame=df , x = 'age' , color ='gender',marginal='box'
        ,title='Distribution of Age with Gender'))
        
    with tab2:
        st.plotly_chart(px.histogram(data_frame=df , x='family size',color='gender' , text_auto=True
        ,title='Distribution of Family Size with Gender'))
        
    with tab3:
        st.plotly_chart(px.histogram(data_frame=df , x='educational qualifications', color='gender',
            category_orders={'educational qualifications': df['educational qualifications'].value_counts().index}
            ,title='Distribution of Educational Qualifications with Gender'))
    
    with tab4:
        st.plotly_chart(px.histogram(data_frame=df , x='marital status',color='gender'
        ,title='Distribution of Marital Status with Gender'))
        
    with tab5:
        st.plotly_chart(px.histogram(data_frame=df , x='feedback' , color='gender',text_auto=True
        ,title='Distribution of Feedback with Gender'))

    with tab6:
        st.plotly_chart(px.histogram(data_frame=df , x='occupation' , color='gender',
            category_orders={'occupation ': df['occupation'].value_counts().index},text_auto=True
        ,title='Distribution of Occupation with Gender'))
        
####################################################################################################

def family():
    
    tab1 , tab2 , tab3 , tab4= st.tabs(['Age' , 'Marital Status','Eduactional','Occupation'])
    
    with tab1:
        average_family_size = df.groupby(['age','occupation'])['family size'].mean().reset_index()
        fig = px.bar(average_family_size, x='age', y='family size',color = 'occupation', 
             labels={'age': 'age', 'family size': 'Average Family Size'},
             title='Average Family Size by age')
        st.plotly_chart(fig)
        
    with tab2:
        average_family_size = df.groupby('marital status')['family size'].mean().reset_index()
        fig = px.bar(average_family_size, x='marital status', y='family size', 
             labels={'marital status': 'marital status', 'family size': 'Average Family Size'},
             title='Average Family Size by Marital Status')
        st.plotly_chart(fig)
        
    with tab3:
        average_family_size = df.groupby('educational qualifications')['family size'].mean().reset_index()
        fig = px.bar(average_family_size, x='educational qualifications', y='family size', 
             labels={'educational qualifications': 'Educational Qualifications', 'family size': 'Average Family Size'},
             title='Average Family Size by Educational Qualifications')
        st.plotly_chart(fig)
        
    with tab4:
        average_family_size = df.groupby('occupation')['family size'].mean().reset_index()
        fig = px.bar(average_family_size, x='occupation', y='family size', 
             labels={'occupation': 'Occupation', 'family size': 'Average Family Size'},
             title='Average Family Size by Occupation')
        st.plotly_chart(fig)
        
############################################################################################

def order_count():
        order_counts_by_occupation = df['occupation'].value_counts().reset_index()
        order_counts_by_occupation.columns = ['Occupation', 'Order Counts']
        
        fig = px.bar(order_counts_by_occupation, x='Occupation', y='Order Counts', 
             title='Order Counts by Occupation',
             labels={'Occupation': 'Occupation', 'Order Counts': 'Order Counts'})
        st.plotly_chart(fig)

##########################################################################################        

def marital():
    
    tab1 , tab2 = st.tabs(['Occupation','Educational'])
    
    
    with tab1:
        st.plotly_chart(px.histogram(data_frame=df , x='educational qualifications' , color='marital status'
            ,text_auto=True , title='Distribution of Educational Qualifications with Marital Status'))
    
    with tab2:
        st.plotly_chart(px.histogram(data_frame=df , x='occupation' , color='marital status'
            ,text_auto=True , title='Distribution ofOccupation with Marital Status'))
        
##############################################################################################

def map_():
    
    import folium
    from streamlit_folium import folium_static

    m = folium.Map(location=[df['latitude'].mean(), df['longitude'].mean()], zoom_start=10)
        
    for index, row in df.iterrows():
        folium.Marker([row['latitude'], row['longitude']], popup=f"Pin code: {row['pin code']}").add_to(m)
    folium_map_html = folium_static(m)

    st.components.v1.html(folium_map_html, width=800, height=600)
        
pages = {'income' : income,
        'gender':gender,
         'family':family,
         'order_count': order_count,
         'marital':marital,
         'map_':map_
        }
pg = st.sidebar.radio('Navigate Pages' , pages.keys())

pages[pg]()
# Out:
# Overwriting app1.py

# %%
! streamlit run app1.py
# Out:
# ^C
